# %%
import matplotlib.pylab as mlp
import numpy as np

# %%
x=[1,2,3,4,5,6]
y=[3,4,5,7,6,4]
mlp.plot(x,y)
mlp.show()

# %%
data1 = np.random.normal(9,2,10)
data1
# Out:
# array([11.3516386 ,  9.2879171 ,  9.82689411,  6.6056742 ,  6.78142818,
#        10.37449651, 12.27584803,  9.30051801,  8.09306933,  8.17675029])
