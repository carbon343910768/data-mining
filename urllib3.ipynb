# %%
# -*- coding:UTF-8 -*-
import urllib3

# %%
http=urllib3.PoolManager()
data = http.request('GET','https://read.douban.com/provider/all')
data.data
# Out:
# /home/carbon13/miniconda2/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
import re
import os

# %%
wd = 'baidu'
url = 'https://cn.bing.com/search?q=' + wd 
url
http=urllib3.PoolManager()
data = http.request('GET',url)
data.data
# Out:
# /home/carbon13/miniconda2/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
import urllib3.exceptions

# %%
try:
    data2 = http.request('GET','https://blog.csdn.net/weixin_42098860?utm_source=feed')
except urllib3.exceptions.HTTPError as e:
    if hasattr(e,'code'):
        print(e.code)
    if hasattr(e,'reason'):
        print(e.reason)
data2.data
# Out:
# /home/carbon13/miniconda2/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
